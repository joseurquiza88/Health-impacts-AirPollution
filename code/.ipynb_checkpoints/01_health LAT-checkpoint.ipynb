# %% [markdown]
# # Paper Health impacts of air pollution exposure from 1990 to 2019 in 43 European countries
#
# Autores:
# Alen Juginović1*, Miro Vuković2, Ivan Aranza2 & Valentina Biloš2

# %%
# Library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
import os
import pandas as pd
# ubicacion de los archivos
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.linear_model import LinearRegression
from scipy.stats import spearmanr
print("librerias ok")
# Out:
# librerias ok

# %%
#Directorio
os.chdir("D:/Josefina/Proyectos/Seba/health_impact/data")
data = pd.read_csv("LAT.csv")
data
# Out:
#       Measure  Metric                                      Risk       Cause  \
# 0      Deaths  Number                             Air pollution  All causes
# 1      Deaths  Number      Ambient particulate matter pollution  All causes
# 2      Deaths  Number  Household air pollution from solid fuels  All causes
# 3      Deaths  Number                   Ambient ozone pollution  All causes
# 4      Deaths    Rate                             Air pollution  All causes
# ...       ...     ...                                       ...         ...
# 12063   DALYs    Rate                   Ambient ozone pollution  All causes
# 12064   DALYs    Rate                             Air pollution  All causes
# 12065   DALYs    Rate      Ambient particulate matter pollution  All causes
# 12066   DALYs    Rate  Household air pollution from solid fuels  All causes
# 12067   DALYs    Rate                   Ambient ozone pollution  All causes
#
#                                Location               Age         Sex    Year  \
# 0      Saint Vincent and the Grenadines          All ages  Both sexes  1990.0
# 1      Saint Vincent and the Grenadines          All ages  Both sexes  1990.0
# 2      Saint Vincent and the Grenadines          All ages  Both sexes  1990.0
# 3      Saint Vincent and the Grenadines          All ages  Both sexes  1990.0
# 4      Saint Vincent and the Grenadines          All ages  Both sexes  1990.0
# ...                                 ...               ...         ...     ...
# 12063                        Costa Rica  Age-standardized        Male  2019.0
# 12064                        Costa Rica  Age-standardized      Female  2019.0
# 12065                        Costa Rica  Age-standardized      Female  2019.0
# 12066                        Costa Rica  Age-standardized      Female  2019.0
# 12067                        Costa Rica  Age-standardized      Female  2019.0
#
#         Value   Upper   Lower  Unnamed: 11
# 0       65.28   93.67   41.22          NaN
# 1       28.87   61.93    8.80          NaN
# 2       36.33   49.85   23.87          NaN
# 3        0.12    0.43    0.00          NaN
# 4       59.32   85.10   37.45          NaN
# ...       ...     ...     ...          ...
# 12063    9.59   20.85    2.83          NaN
# 12064  464.85  622.12  325.08          NaN
# 12065  399.34  539.25  274.24          NaN
# 12066   60.35  119.15   25.11          NaN
# 12067    5.99   12.71    1.65          NaN
#
# [12068 rows x 12 columns]

# %% [markdown]
# # Tabla 1

# %%
# ALL CAUSES
## --------  Air pollution
num_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Air pollution = ",round(num_death_airPol_allCause['Value'].sum()/1000,1))
##
rate_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_allCause = round(np.percentile(rate_death_airPol_allCause['Value'], 75) - np.percentile(rate_death_airPol_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_death_airPol_allCause['Value'].median(),1),"(",IQR_rate_death_airPol_allCause,")")
##
rate_DALYs_airPol_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_allCause = round(np.percentile(rate_DALYs_airPol_allCause['Value'], 75) - np.percentile(rate_DALYs_airPol_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_DALYs_airPol_allCause['Value'].median(),1),"(",IQR_rate_DALYs_airPol_allCause,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - aPM2.5 = ",round(num_death_apm25_allCause['Value'].sum()/1000,1))
##
rate_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_allCause = round(np.percentile(rate_death_apm25_allCause['Value'], 75) - np.percentile(rate_death_apm25_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_death_apm25_allCause['Value'].median(),1),"(",IQR_rate_death_apm25_allCause,")")
##
rate_DALYs_apm25_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_allCause = round(np.percentile(rate_DALYs_apm25_allCause['Value'], 75) - np.percentile(rate_DALYs_apm25_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_DALYs_apm25_allCause['Value'].median(),1),"(",IQR_DALYs_apm25_allCause,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Household = ",round(num_death_household_allCause['Value'].sum()/1000,1))
##
rate_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_household_allCause  = round(np.percentile(rate_death_household_allCause['Value'], 75) - np.percentile(rate_death_household_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Household = ",round(rate_death_household_allCause['Value'].median(),1),"(",IQR_death_household_allCause,")")
##
rate_DALYs_household_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_household_allCause  = round(np.percentile(rate_DALYs_household_allCause['Value'], 75) - np.percentile(rate_DALYs_household_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household = ",round(rate_DALYs_household_allCause['Value'].median(),1),"(",IQR_DALYs_household_allCause,")")
print("-------------------------------------------------------")


## ----------- Ambient ozone pollution
num_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient ozone pollution') & (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Ozone - Household = ",round(num_death_ozone_allCause['Value'].sum()/1000,1))
##
rate_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_ozone_allCause  = round(np.percentile(rate_death_ozone_allCause['Value'], 75) - np.percentile(rate_death_ozone_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_death_ozone_allCause['Value'].median(),1),"(",IQR_death_ozone_allCause,")")
##
rate_DALYs_ozone_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_ozone_allCause = round(np.percentile(rate_DALYs_ozone_allCause['Value'], 75) - np.percentile(rate_DALYs_ozone_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_DALYs_ozone_allCause['Value'].median(),1),"(",IQR_DALYs_ozone_allCause,")")
print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - All causes - Air pollution =  608.0
# Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution =  39.9 ( 25.4 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution =  1080.8 ( 686.8 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - aPM2.5 =  435.1
# Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 =  30.6 ( 15.5 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 =  786.1 ( 510.3 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - Household =  153.9
# Median age standardised death rate per 100,000 (IQR) - All causes - Household =  3.6 ( 8.5 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household =  108.2 ( 248.9 )
# -------------------------------------------------------
# Deaths (thousands) - Ozone - Household =  22.1
# Median age standardised death rate per 100,000 (IQR) - All causes - Ozone =  0.5 ( 0.8 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone =  7.1 ( 14.3 )
# -------------------------------------------------------

# %%
# ischemic heart disease
## --------  Air pollution
num_death_airPol_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Ischemic heart disease - Air pollution = ",round(num_death_airPol_IHD['Value'].sum()/1000,1))
##
rate_death_airPol_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_IHD = round(np.percentile(rate_death_airPol_IHD['Value'], 75) - np.percentile(rate_death_airPol_IHD['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - Ischemic heart disease - Air pollution = ",round(rate_death_airPol_IHD['Value'].median(),1),"(",IQR_rate_death_airPol_IHD,")")
##
rate_DALYs_airPol_IHD = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_IHD = round(np.percentile(rate_DALYs_airPol_IHD['Value'], 75) - np.percentile(rate_DALYs_airPol_IHD['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - Air pollution = ",round(rate_DALYs_airPol_IHD['Value'].median(),1),"(",IQR_rate_DALYs_airPol_IHD,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Ischemic heart disease - aPM2.5 = ",round(num_death_apm25_IHD['Value'].sum()/1000,1))
##
rate_death_apm25_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_IHD = round(np.percentile(rate_death_apm25_IHD['Value'], 75) - np.percentile(rate_death_apm25_IHD['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - Ischemic heart disease - aPM2.5 = ",round(rate_death_apm25_IHD['Value'].median(),1),"(",IQR_rate_death_apm25_IHD,")")
##
rate_DALYs_apm25_IHD = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_IHD = round(np.percentile(rate_DALYs_apm25_IHD['Value'], 75) - np.percentile(rate_DALYs_apm25_IHD['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - aPM2.5 = ",round(rate_DALYs_apm25_IHD['Value'].median(),1),"(",IQR_DALYs_apm25_IHD,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Ischemic heart disease - Household = ",round(num_death_household_IHD['Value'].sum()/1000,1))
##
rate_death_household_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
IQR_death_household_IHD  = round(np.percentile(rate_death_household_IHD['Value'], 75) - np.percentile(rate_death_household_IHD['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - Ischemic heart disease- Household = ",round(rate_death_household_IHD['Value'].median(),1),"(",IQR_death_household_IHD,")")
##
rate_DALYs_household_IHD = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
IQR_DALYs_household_IHD  = round(np.percentile(rate_DALYs_household_IHD['Value'], 75) - np.percentile(rate_DALYs_household_IHD['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - Household = ",round(rate_DALYs_household_IHD['Value'].median(),1),"(",IQR_DALYs_household_IHD,")")
print("-------------------------------------------------------")


## ----------- Ambient ozone pollution
# num_death_ozone_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient ozone pollution') & (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
# print("Deaths (thousands) - Ozone - Household = ",round(num_death_ozone_IHD['Value'].sum()/1000,1))
# ##
# rate_death_ozone_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
# IQR_death_ozone_IHD  = round(np.percentile(rate_death_ozone_IHD['Value'], 75) - np.percentile(rate_death_ozone_IHD['Value'], 25),1)

# print("Median age standardised death rate per 100,000 (IQR) -Ischemic heart disease - Ozone = ",round(rate_death_ozone_IHD['Value'].median(),1),"(",IQR_death_ozone_IHD,")")
# ##
# rate_DALYs_ozone_IHD = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
# IQR_DALYs_ozone_IHD = round(np.percentile(rate_DALYs_ozone_IHD['Value'], 75) - np.percentile(rate_DALYs_ozone_IHD['Value'], 25),1)

# print("Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - Ozone = ",round(rate_DALYs_ozone_IHD['Value'].median(),1),"(",IQR_DALYs_ozone_IHD,")")
# print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - Ischemic heart disease - Air pollution =  164.3
# Median age standardised death rate per 100,000 (IQR) - Ischemic heart disease - Air pollution =  6.5 ( 17.2 )
# Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - Air pollution =  133.5 ( 347.1 )
# -------------------------------------------------------
# Deaths (thousands) - Ischemic heart disease - aPM2.5 =  155.1
# Median age standardised death rate per 100,000 (IQR) - Ischemic heart disease - aPM2.5 =  6.0 ( 14.0 )
# Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - aPM2.5 =  124.8 ( 290.0 )
# -------------------------------------------------------
# Deaths (thousands) - Ischemic heart disease - Household =  9.2
# Median age standardised death rate per 100,000 (IQR) - Ischemic heart disease- Household =  0.1 ( 1.5 )
# Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - Household =  1.0 ( 27.9 )
# -------------------------------------------------------

# %%
# STROKE
## --------  Air pollution
num_death_airPol_Stroke = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Stroke- Air pollution = ",round(num_death_airPol_Stroke['Value'].sum()/1000,1))
##
rate_death_airPol_Stroke = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_Stroke = round(np.percentile(rate_death_airPol_Stroke['Value'], 75) - np.percentile(rate_death_airPol_Stroke['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - Stroke - Air pollution = ",round(rate_death_airPol_Stroke['Value'].median(),1),"(",IQR_rate_death_airPol_Stroke,")")
##
rate_DALYs_airPol_Stroke = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_Stroke = round(np.percentile(rate_DALYs_airPol_Stroke['Value'], 75) - np.percentile(rate_DALYs_airPol_Stroke['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - Stroke - Air pollution = ",round(rate_DALYs_airPol_Stroke['Value'].median(),1),"(",IQR_rate_DALYs_airPol_Stroke,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_Stroke = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Strokee - aPM2.5 = ",round(num_death_apm25_Stroke['Value'].sum()/1000,1))
##
rate_death_apm25_Stroke = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_Stroke = round(np.percentile(rate_death_apm25_Stroke['Value'], 75) - np.percentile(rate_death_apm25_Stroke['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - Stroke - aPM2.5 = ",round(rate_death_apm25_Stroke['Value'].median(),1),"(",IQR_rate_death_apm25_Stroke,")")
##
rate_DALYs_apm25_Stroke = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_Stroke = round(np.percentile(rate_DALYs_apm25_Stroke['Value'], 75) - np.percentile(rate_DALYs_apm25_Stroke['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - Stroke- aPM2.5 = ",round(rate_DALYs_apm25_Stroke['Value'].median(),1),"(",IQR_DALYs_apm25_Stroke,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_Stroke = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Stroke - Household = ",round(num_death_household_Stroke['Value'].sum()/1000,1))
##
rate_death_household_Stroke = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
IQR_death_household_Stroke  = round(np.percentile(rate_death_household_Stroke['Value'], 75) - np.percentile(rate_death_household_Stroke['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - Stroke - Household = ",round(rate_death_household_Stroke['Value'].median(),1),"(",IQR_death_household_Stroke,")")
##
rate_DALYs_household_Stroke = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Stroke')  & (data['Year'] == 2019)]
IQR_DALYs_household_Stroke  = round(np.percentile(rate_DALYs_household_Stroke['Value'], 75) - np.percentile(rate_DALYs_household_Stroke['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - Stroke - Household = ",round(rate_DALYs_household_Stroke['Value'].median(),1),"(",IQR_DALYs_household_Stroke,")")
print("-------------------------------------------------------")


## ----------- Ambient ozone pollution
# num_death_ozone_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient ozone pollution') & (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
# print("Deaths (thousands) - Ozone - Household = ",round(num_death_ozone_IHD['Value'].sum()/1000,1))
# ##
# rate_death_ozone_IHD = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
# IQR_death_ozone_IHD  = round(np.percentile(rate_death_ozone_IHD['Value'], 75) - np.percentile(rate_death_ozone_IHD['Value'], 25),1)

# print("Median age standardised death rate per 100,000 (IQR) -Ischemic heart disease - Ozone = ",round(rate_death_ozone_IHD['Value'].median(),1),"(",IQR_death_ozone_IHD,")")
# ##
# rate_DALYs_ozone_IHD = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Ischemic heart disease')  & (data['Year'] == 2019)]
# IQR_DALYs_ozone_IHD = round(np.percentile(rate_DALYs_ozone_IHD['Value'], 75) - np.percentile(rate_DALYs_ozone_IHD['Value'], 25),1)

# print("Median age standardised DALYs rate per 100,000 (IQR) - Ischemic heart disease - Ozone = ",round(rate_DALYs_ozone_IHD['Value'].median(),1),"(",IQR_DALYs_ozone_IHD,")")
# print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - Stroke- Air pollution =  92.7
# Median age standardised death rate per 100,000 (IQR) - Stroke - Air pollution =  3.2 ( 8.7 )
# Median age standardised DALYs rate per 100,000 (IQR) - Stroke - Air pollution =  64.4 ( 202.8 )
# -------------------------------------------------------
# Deaths (thousands) - Strokee - aPM2.5 =  86.4
# Median age standardised death rate per 100,000 (IQR) - Stroke - aPM2.5 =  3.2 ( 7.8 )
# Median age standardised DALYs rate per 100,000 (IQR) - Stroke- aPM2.5 =  64.1 ( 187.1 )
# -------------------------------------------------------
# Deaths (thousands) - Stroke - Household =  6.3
# Median age standardised death rate per 100,000 (IQR) - Stroke - Household =  0.0 ( 0.8 )
# Median age standardised DALYs rate per 100,000 (IQR) - Stroke - Household =  0.7 ( 17.9 )
# -------------------------------------------------------

# %%
# stroke
## --------  Air pollution
num_death_airPol_TRL= data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Tracheal, bronchus, and lung cancer- Air pollution = ",round(num_death_airPol_TRL['Value'].sum()/1000,1))
##
rate_death_airPol_TRL = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_TRL = round(np.percentile(rate_death_airPol_TRL['Value'], 75) - np.percentile(rate_death_airPol_TRL['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Air pollution = ",round(rate_death_airPol_TRL['Value'].median(),1),"(",IQR_rate_death_airPol_TRL,")")
##
rate_DALYs_airPol_TRL = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_TRL = round(np.percentile(rate_DALYs_airPol_TRL['Value'], 75) - np.percentile(rate_DALYs_airPol_TRL['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Air pollution = ",round(rate_DALYs_airPol_TRL['Value'].median(),1),"(",IQR_rate_DALYs_airPol_TRL,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_TRL = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Tracheal, bronchus, and lung cancere - aPM2.5 = ",round(num_death_apm25_TRL['Value'].sum()/1000,1))
##
rate_death_apm25_TRL = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_TRL = round(np.percentile(rate_death_apm25_TRL['Value'], 75) - np.percentile(rate_death_apm25_TRL['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - aPM2.5 = ",round(rate_death_apm25_TRL['Value'].median(),1),"(",IQR_rate_death_apm25_TRL,")")
##
rate_DALYs_apm25_TRL = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_TRL = round(np.percentile(rate_DALYs_apm25_TRL['Value'], 75) - np.percentile(rate_DALYs_apm25_TRL['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer- aPM2.5 = ",round(rate_DALYs_apm25_TRL['Value'].median(),1),"(",IQR_DALYs_apm25_TRL,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_TRL = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
print("Deaths (thousands) - Tracheal, bronchus, and lung cancer - Household = ",round(num_death_household_TRL['Value'].sum()/1000,1))
##
rate_death_household_TRL = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
IQR_death_household_TRL  = round(np.percentile(rate_death_household_TRL['Value'], 75) - np.percentile(rate_death_household_TRL['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Household = ",round(rate_death_household_TRL['Value'].median(),1),"(",IQR_death_household_TRL,")")
##
rate_DALYs_household_TRL = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'Tracheal, bronchus, and lung cancer')  & (data['Year'] == 2019)]
IQR_DALYs_household_TRL  = round(np.percentile(rate_DALYs_household_TRL['Value'], 75) - np.percentile(rate_DALYs_household_TRL['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Household = ",round(rate_DALYs_household_TRL['Value'].median(),1),"(",IQR_DALYs_household_TRL,")")
print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - Tracheal, bronchus, and lung cancer- Air pollution =  39.5
# Median age standardised death rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Air pollution =  2.4 ( 2.1 )
# Median age standardised DALYs rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Air pollution =  55.6 ( 56.4 )
# -------------------------------------------------------
# Deaths (thousands) - Tracheal, bronchus, and lung cancere - aPM2.5 =  37.7
# Median age standardised death rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - aPM2.5 =  2.3 ( 1.9 )
# Median age standardised DALYs rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer- aPM2.5 =  55.5 ( 44.5 )
# -------------------------------------------------------
# Deaths (thousands) - Tracheal, bronchus, and lung cancer - Household =  1.8
# Median age standardised death rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Household =  0.0 ( 0.2 )
# Median age standardised DALYs rate per 100,000 (IQR) - Tracheal, bronchus, and lung cancer - Household =  0.6 ( 5.2 )
# -------------------------------------------------------

# %%
# ALL CAUSES - FEMALE
## --------  Air pollution
num_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Females')& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Air pollution = ",round(num_death_airPol_allCause['Value'].sum()/1000,1))
##
rate_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_allCause = round(np.percentile(rate_death_airPol_allCause['Value'], 75) - np.percentile(rate_death_airPol_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_death_airPol_allCause['Value'].median(),1),"(",IQR_rate_death_airPol_allCause,")")
##
rate_DALYs_airPol_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_allCause = round(np.percentile(rate_DALYs_airPol_allCause['Value'], 75) - np.percentile(rate_DALYs_airPol_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_DALYs_airPol_allCause['Value'].median(),1),"(",IQR_rate_DALYs_airPol_allCause,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'All causes')  &(data['Sex'] == 'Females')& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - aPM2.5 = ",round(num_death_apm25_allCause['Value'].sum()/1000,1))
##
rate_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_allCause = round(np.percentile(rate_death_apm25_allCause['Value'], 75) - np.percentile(rate_death_apm25_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_death_apm25_allCause['Value'].median(),1),"(",IQR_rate_death_apm25_allCause,")")
##
rate_DALYs_apm25_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_allCause = round(np.percentile(rate_DALYs_apm25_allCause['Value'], 75) - np.percentile(rate_DALYs_apm25_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_DALYs_apm25_allCause['Value'].median(),1),"(",IQR_DALYs_apm25_allCause,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Females')&(data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Household = ",round(num_death_household_allCause['Value'].sum()/1000,1))
##
rate_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_household_allCause  = round(np.percentile(rate_death_household_allCause['Value'], 75) - np.percentile(rate_death_household_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Household = ",round(rate_death_household_allCause['Value'].median(),1),"(",IQR_death_household_allCause,")")
##
rate_DALYs_household_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_household_allCause  = round(np.percentile(rate_DALYs_household_allCause['Value'], 75) - np.percentile(rate_DALYs_household_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household = ",round(rate_DALYs_household_allCause['Value'].median(),1),"(",IQR_DALYs_household_allCause,")")
print("-------------------------------------------------------")


## ----------- Ambient ozone pollution
num_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient ozone pollution') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Females')& (data['Year'] == 2019)]
print("Deaths (thousands) - Ozone - Household = ",round(num_death_ozone_allCause['Value'].sum()/1000,1))
##
rate_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_ozone_allCause  = round(np.percentile(rate_death_ozone_allCause['Value'], 75) - np.percentile(rate_death_ozone_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_death_ozone_allCause['Value'].median(),1),"(",IQR_death_ozone_allCause,")")
##
rate_DALYs_ozone_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Females')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_ozone_allCause = round(np.percentile(rate_DALYs_ozone_allCause['Value'], 75) - np.percentile(rate_DALYs_ozone_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_DALYs_ozone_allCause['Value'].median(),1),"(",IQR_DALYs_ozone_allCause,")")
print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - All causes - Air pollution =  174.1
# Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution =  11.7 ( 24.9 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution =  283.2 ( 570.9 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - aPM2.5 =  156.5
# Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 =  10.7 ( 21.1 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 =  274.9 ( 467.2 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - Household =  11.2
# Median age standardised death rate per 100,000 (IQR) - All causes - Household =  0.1 ( 2.6 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household =  3.3 ( 57.6 )
# -------------------------------------------------------
# Deaths (thousands) - Ozone - Household =  7.1
# Median age standardised death rate per 100,000 (IQR) - All causes - Ozone =  0.6 ( 0.6 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone =  8.1 ( 8.5 )
# -------------------------------------------------------

# %%
# ALL CAUSES - MALES
## --------  Air pollution
num_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Males')& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Air pollution = ",round(num_death_airPol_allCause['Value'].sum()/1000,1))
##
rate_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_allCause = round(np.percentile(rate_death_airPol_allCause['Value'], 75) - np.percentile(rate_death_airPol_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_death_airPol_allCause['Value'].median(),1),"(",IQR_rate_death_airPol_allCause,")")
##
rate_DALYs_airPol_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_allCause = round(np.percentile(rate_DALYs_airPol_allCause['Value'], 75) - np.percentile(rate_DALYs_airPol_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_DALYs_airPol_allCause['Value'].median(),1),"(",IQR_rate_DALYs_airPol_allCause,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'All causes')  &(data['Sex'] == 'Males')& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - aPM2.5 = ",round(num_death_apm25_allCause['Value'].sum()/1000,1))
##
rate_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_allCause = round(np.percentile(rate_death_apm25_allCause['Value'], 75) - np.percentile(rate_death_apm25_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_death_apm25_allCause['Value'].median(),1),"(",IQR_rate_death_apm25_allCause,")")
##
rate_DALYs_apm25_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_allCause = round(np.percentile(rate_DALYs_apm25_allCause['Value'], 75) - np.percentile(rate_DALYs_apm25_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_DALYs_apm25_allCause['Value'].median(),1),"(",IQR_DALYs_apm25_allCause,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Males')&(data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Household = ",round(num_death_household_allCause['Value'].sum()/1000,1))
##
rate_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_household_allCause  = round(np.percentile(rate_death_household_allCause['Value'], 75) - np.percentile(rate_death_household_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Household = ",round(rate_death_household_allCause['Value'].median(),1),"(",IQR_death_household_allCause,")")
##
rate_DALYs_household_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_household_allCause  = round(np.percentile(rate_DALYs_household_allCause['Value'], 75) - np.percentile(rate_DALYs_household_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household = ",round(rate_DALYs_household_allCause['Value'].median(),1),"(",IQR_DALYs_household_allCause,")")
print("-------------------------------------------------------")


## ----------- Ambient ozone pollution
num_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient ozone pollution') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Males')& (data['Year'] == 2019)]
print("Deaths (thousands) - Ozone - Household = ",round(num_death_ozone_allCause['Value'].sum()/1000,1))
##
rate_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_ozone_allCause  = round(np.percentile(rate_death_ozone_allCause['Value'], 75) - np.percentile(rate_death_ozone_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_death_ozone_allCause['Value'].median(),1),"(",IQR_death_ozone_allCause,")")
##
rate_DALYs_ozone_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == 'Age-standardized')& (data['Sex'] == 'Males')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_ozone_allCause = round(np.percentile(rate_DALYs_ozone_allCause['Value'], 75) - np.percentile(rate_DALYs_ozone_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_DALYs_ozone_allCause['Value'].median(),1),"(",IQR_DALYs_ozone_allCause,")")
print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - All causes - Air pollution =  193.9
# Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution =  23.6 ( 43.7 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution =  537.7 ( 1107.6 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - aPM2.5 =  176.3
# Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 =  20.9 ( 37.5 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 =  500.1 ( 892.3 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - Household =  8.4
# Median age standardised death rate per 100,000 (IQR) - All causes - Household =  0.2 ( 3.4 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household =  4.4 ( 86.6 )
# -------------------------------------------------------
# Deaths (thousands) - Ozone - Household =  10.2
# Median age standardised death rate per 100,000 (IQR) - All causes - Ozone =  1.5 ( 1.1 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone =  23.2 ( 16.7 )
# -------------------------------------------------------

# %%
# ALL CAUSES - -5 años
## --------  Air pollution
num_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Both sexes')& (data['Age'] == "<5 years")& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Air pollution = ",round(num_death_airPol_allCause['Value'].sum()/1000,1))
##
rate_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == "<5 years")& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_allCause = round(np.percentile(rate_death_airPol_allCause['Value'], 75) - np.percentile(rate_death_airPol_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_death_airPol_allCause['Value'].median(),1),"(",IQR_rate_death_airPol_allCause,")")
##
rate_DALYs_airPol_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == "<5 years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_allCause = round(np.percentile(rate_DALYs_airPol_allCause['Value'], 75) - np.percentile(rate_DALYs_airPol_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_DALYs_airPol_allCause['Value'].median(),1),"(",IQR_rate_DALYs_airPol_allCause,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'All causes')& (data['Age'] == "<5 years")  &(data['Sex'] =="Both sexes")& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - aPM2.5 = ",round(num_death_apm25_allCause['Value'].sum()/1000,1))
##
rate_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == "<5 years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_allCause = round(np.percentile(rate_death_apm25_allCause['Value'], 75) - np.percentile(rate_death_apm25_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_death_apm25_allCause['Value'].median(),1),"(",IQR_rate_death_apm25_allCause,")")
##
rate_DALYs_apm25_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == "<5 years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_allCause = round(np.percentile(rate_DALYs_apm25_allCause['Value'], 75) - np.percentile(rate_DALYs_apm25_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_DALYs_apm25_allCause['Value'].median(),1),"(",IQR_DALYs_apm25_allCause,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels')& (data['Age'] == "<5 years") & (data['Cause'] == 'All causes')  & (data['Sex'] == "Both sexes")&(data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Household = ",round(num_death_household_allCause['Value'].sum()/1000,1))
##
rate_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == "<5 years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_household_allCause  = round(np.percentile(rate_death_household_allCause['Value'], 75) - np.percentile(rate_death_household_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Household = ",round(rate_death_household_allCause['Value'].median(),1),"(",IQR_death_household_allCause,")")
##
rate_DALYs_household_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == "<5 years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_household_allCause  = round(np.percentile(rate_DALYs_household_allCause['Value'], 75) - np.percentile(rate_DALYs_household_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household = ",round(rate_DALYs_household_allCause['Value'].median(),1),"(",IQR_DALYs_household_allCause,")")
print("-------------------------------------------------------")


## ----------- Ambient ozone pollution
num_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient ozone pollution') & (data['Cause'] == 'All causes')& (data['Age'] == "<5 years")  & (data['Sex'] == "Both sexes")& (data['Year'] == 2019)]
print("Deaths (thousands) - Ozone - Household = ",round(num_death_ozone_allCause['Value'].sum()/1000,1))
##
rate_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == "<5 years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_ozone_allCause  = round(np.percentile(rate_death_ozone_allCause['Value'], 75) - np.percentile(rate_death_ozone_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_death_ozone_allCause['Value'].median(),1),"(",IQR_death_ozone_allCause,")")
##
rate_DALYs_ozone_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == "<5 years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_ozone_allCause = round(np.percentile(rate_DALYs_ozone_allCause['Value'], 75) - np.percentile(rate_DALYs_ozone_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_DALYs_ozone_allCause['Value'].median(),1),"(",IQR_DALYs_ozone_allCause,")")
print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - All causes - Air pollution =  1.0
# Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution =  1.9 ( 1.8 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution =  168.2 ( 163.1 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - aPM2.5 =  0.9
# Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 =  1.8 ( 1.7 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 =  163.8 ( 151.7 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - Household =  0.1
# Median age standardised death rate per 100,000 (IQR) - All causes - Household =  0.0 ( 0.3 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household =  1.9 ( 23.0 )
# -------------------------------------------------------
# Deaths (thousands) - Ozone - Household =  0.0
# Median age standardised death rate per 100,000 (IQR) - All causes - Ozone =  0.0 ( 0.0 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone =  0.0 ( 0.0 )
# -------------------------------------------------------

# %%
# ALL CAUSES - MALES
## --------  Air pollution
num_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes')  & (data['Sex'] == 'Both sexes')& (data['Age'] == "70+ years")& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Air pollution = ",round(num_death_airPol_allCause['Value'].sum()/1000,1))
##
rate_death_airPol_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == "70+ years")& (data['Sex'] == 'Both sexes')& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
# Calcular el IQR
IQR_rate_death_airPol_allCause = round(np.percentile(rate_death_airPol_allCause['Value'], 75) - np.percentile(rate_death_airPol_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_death_airPol_allCause['Value'].median(),1),"(",IQR_rate_death_airPol_allCause,")")
##
rate_DALYs_airPol_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Age'] == "70+ years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_DALYs_airPol_allCause = round(np.percentile(rate_DALYs_airPol_allCause['Value'], 75) - np.percentile(rate_DALYs_airPol_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution = ",round(rate_DALYs_airPol_allCause['Value'].median(),1),"(",IQR_rate_DALYs_airPol_allCause,")")

print("-------------------------------------------------------")
## ----------- Ambient particulate matter pollution
num_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Cause'] == 'All causes')& (data['Age'] == "70+ years")  &(data['Sex'] =="Both sexes")& (data['Year'] == 2019)]
print("Deaths (thousands) - All causes - aPM2.5 = ",round(num_death_apm25_allCause['Value'].sum()/1000,1))
##
rate_death_apm25_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == "70+ years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_rate_death_apm25_allCause = round(np.percentile(rate_death_apm25_allCause['Value'], 75) - np.percentile(rate_death_apm25_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_death_apm25_allCause['Value'].median(),1),"(",IQR_rate_death_apm25_allCause,")")
##
rate_DALYs_apm25_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient particulate matter pollution') & (data['Age'] == "70+ years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_apm25_allCause = round(np.percentile(rate_DALYs_apm25_allCause['Value'], 75) - np.percentile(rate_DALYs_apm25_allCause['Value'], 25),1)
print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 = ",round(rate_DALYs_apm25_allCause['Value'].median(),1),"(",IQR_DALYs_apm25_allCause,")")

print("-------------------------------------------------------")
## ----------- Household air pollution from solid fuels 
num_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Household air pollution from solid fuels')& (data['Age'] == "70+ years") & (data['Cause'] == 'All causes')  & (data['Sex'] == "Both sexes")&(data['Year'] == 2019)]
print("Deaths (thousands) - All causes - Household = ",round(num_death_household_allCause['Value'].sum()/1000,1))
##
rate_death_household_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == "70+ years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_household_allCause  = round(np.percentile(rate_death_household_allCause['Value'], 75) - np.percentile(rate_death_household_allCause['Value'], 25),1)
print("Median age standardised death rate per 100,000 (IQR) - All causes - Household = ",round(rate_death_household_allCause['Value'].median(),1),"(",IQR_death_household_allCause,")")
##
rate_DALYs_household_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Household air pollution from solid fuels') & (data['Age'] == "70+ years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_household_allCause  = round(np.percentile(rate_DALYs_household_allCause['Value'], 75) - np.percentile(rate_DALYs_household_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household = ",round(rate_DALYs_household_allCause['Value'].median(),1),"(",IQR_DALYs_household_allCause,")")
print("-------------------------------------------------------")


## ----------- Ambient ozone pollution
num_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Ambient ozone pollution') & (data['Cause'] == 'All causes')& (data['Age'] == "70+ years")  & (data['Sex'] == "Both sexes")& (data['Year'] == 2019)]
print("Deaths (thousands) - Ozone - Household = ",round(num_death_ozone_allCause['Value'].sum()/1000,1))
##
rate_death_ozone_allCause = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == "70+ years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_death_ozone_allCause  = round(np.percentile(rate_death_ozone_allCause['Value'], 75) - np.percentile(rate_death_ozone_allCause['Value'], 25),1)

print("Median age standardised death rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_death_ozone_allCause['Value'].median(),1),"(",IQR_death_ozone_allCause,")")
##
rate_DALYs_ozone_allCause = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Ambient ozone pollution') & (data['Age'] == "70+ years")& (data['Sex'] == "Both sexes")& (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
IQR_DALYs_ozone_allCause = round(np.percentile(rate_DALYs_ozone_allCause['Value'], 75) - np.percentile(rate_DALYs_ozone_allCause['Value'], 25),1)

print("Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone = ",round(rate_DALYs_ozone_allCause['Value'].median(),1),"(",IQR_DALYs_ozone_allCause,")")
print("-------------------------------------------------------")
# Out:
# Deaths (thousands) - All causes - Air pollution =  249.9
# Median age standardised death rate per 100,000 (IQR) - All causes - Air pollution =  226.7 ( 308.1 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Air pollution =  3034.8 ( 4523.9 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - aPM2.5 =  223.5
# Median age standardised death rate per 100,000 (IQR) - All causes - aPM2.5 =  197.5 ( 284.5 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - aPM2.5 =  2731.6 ( 4079.0 )
# -------------------------------------------------------
# Deaths (thousands) - All causes - Household =  13.1
# Median age standardised death rate per 100,000 (IQR) - All causes - Household =  1.9 ( 31.3 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Household =  27.4 ( 455.3 )
# -------------------------------------------------------
# Deaths (thousands) - Ozone - Household =  14.6
# Median age standardised death rate per 100,000 (IQR) - All causes - Ozone =  11.1 ( 11.4 )
# Median age standardised DALYs rate per 100,000 (IQR) - All causes - Ozone =  140.9 ( 128.8 )
# -------------------------------------------------------

# %%
# Funcion para filtrar los datos de las columnas
def filtrado (data, Measure, Metric, Risk, Cause, Age, Sex, Year):
    df_filtrado = data[(data['Measure'] == Measure) & (data['Metric'] == Metric) & (data['Risk'] == Risk) & (data['Age'] == Age)& (data['Sex'] == Sex)& (data['Cause'] == Cause)  & (data['Year'] == Year)]
    return df_filtrado

prueba_filtro = filtrado (data = data, Measure = "DALYs", Metric = 'Rate', Risk = 'Ambient ozone pollution', Cause='All causes', Age = "70+ years", Sex="Both sexes", Year=2019)
len(prueba_filtro)
# Out:
# 43

# %% [markdown]
# # Figure 2. Percent change in number of deaths attributable to air pollution in 2019 compared to 1990.

# %%
# Filtramos los datos de numeros de muertes atribuible solo a la contaminacion atmosferica tanto para el año 1990 como para 2019
#Año 1990
num_death_air_pol_1990 = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes')  & (data['Year'] == 1990)]
# Europa len = 43
#len(num_death_air_pol_1990)
#Año 2019
num_death_air_pol_2019 = data[(data['Measure'] == 'Deaths') & (data['Metric'] == 'Number') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes')  & (data['Year'] == 2019)]
# Europa len = 43
#len(num_death_air_pol_2019)

# Union de las tablas de 1990 - 2019 para ser comparadas
num_death_air_pol_merge = pd.merge(num_death_air_pol_1990, num_death_air_pol_2019, on='Location', how='inner')
#print(num_death_air_pol_merge)
# Cambiamos el nombre de las columnas
#print(num_death_air_pol_merge.columns)
num_death_air_pol_merge = num_death_air_pol_merge.rename(columns={'Value_x':"value_1990", 'Value_y':"value_2019"})
# Calculamos el % de cambio
num_death_air_pol_merge['percent_change'] = ((num_death_air_pol_merge['value_2019'] - num_death_air_pol_merge['value_1990']) / num_death_air_pol_merge['value_1990']) *100

#Generamos un df nuevo y solo nos quedamos con las columnas del nombre de los paises y el % de cambio calculado
percent_change_num_death = num_death_air_pol_merge[['Location', 'percent_change']]
# Ordenamos de mayor a menor como esta en el paer
percent_change_num_death = percent_change_num_death.sort_values(by='percent_change',ascending=False)
#print(percent_change_num_death)

# Generamos Gráfico de barras
plt.figure(figsize=(8, 6))
plt.bar(x = percent_change_num_death['Location'], height = percent_change_num_death["percent_change"], width=0.5)
plt.ylim(-100, 40) 
plt.axhline(0, color='black', linestyle='-', linewidth=1)
plt.xticks(rotation=90, fontsize=9)
# Agregar etiquetas a los ejes
plt.xlabel('Location', fontsize=10)  # Etiqueta del eje x
plt.ylabel('Percent change in number of deaths', fontsize=10)  # Etiqueta del eje y

# Agregar título
plt.title('Figure 2. Percent change in number of deaths attributable to air pollution in 2019 compared to 1990', fontsize=16)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Figure 4. Age-standardised YLL rate per 100,000 and average annual population-weighted aPM2.5 in 2019.

# %%
#years of life lost (YLL) 2019
yll_ihd = data[(data['Measure'] == 'YLLs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Cause'] != 'All causes') & (data['Age'] == 'Age-standardized')  & (data['Year'] == 2019)]

# # Europa len = 43 * 3 tipo de enfermedades
len(yll_ihd)

# Agrupar por país y causa, y sumar los valores
df_grouped = yll_ihd.groupby(['Location', 'Cause'])['Value'].sum().unstack()
df_grouped = df_grouped.loc[df_grouped.sum(axis=1).sort_values(ascending=False).index]

# Generamos plot de YLL
# Establecer el tamaño de la figura
plt.figure(figsize=(46, 10))
# Crear un gráfico de barras horizontales apiladas
df_grouped.plot(kind='barh', stacked=True, width=0.7)
# Agregar etiquetas a los ejes
plt.xlabel('Age-standardised YLL rate per 100,000', fontsize=11)
plt.ylabel('Location', fontsize=14)
plt.yticks( fontsize=7)
plt.xlim(0, 2500) 
# Agregar título
plt.title('Figure 4. Age-standardised YLL rate per 100,000 a', fontsize=10)
# Mostrar el gráfico
plt.show()

# %%
#average annual population-weighted aPM2.5 in 2019
data_pm25_2019 = data_pm[data_pm['Year'] == 2019]

# # Europa len = 43 * 3 tipo de enfermedades
len(data_pm25_2019)
data_pm25_2019 = data_pm25_2019.sort_values(by='Exposure Mean',ascending=False)
### PLOT
# Generamos Gráfico de barras
plt.figure(figsize=(8, 6))
# Crear un gráfico de barras horizontales
plt.barh(data_pm25_2019['Country'], data_pm25_2019['Exposure Mean'], height=0.8)
plt.xlim(0, 36) 
# Agregar etiquetas a los ejes
plt.xlabel('Average annual population-weighted aPM2.5')
plt.ylabel('Location')
plt.yticks( fontsize=7)
# Agregar título
plt.title('Figure 4.Average annual population-weighted aPM2.5 in 2019.')

# Mostrar el gráfico
plt.show()

# %%
#Igual que plots anterior pero ponemos dos plots en uno mismo
# Ojo que el orden no esta igual que el paper, pero los valores estan ok
#years of life lost (YLL) 2019
yll_ihd = data[(data['Measure'] == 'YLLs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Cause'] != 'All causes') & (data['Age'] == 'Age-standardized')  & (data['Year'] == 2019)]
# Agrupar por país y causa, y sumar los valores
df_grouped = yll_ihd.groupby(['Location', 'Cause'])['Value'].sum().unstack()
df_grouped = df_grouped.loc[df_grouped.sum(axis=1).sort_values(ascending=False).index]
# Datos de aPM25
data_pm25_2019 = data_pm[data_pm['Year'] == 2019]
data_pm25_2019 = data_pm25_2019.rename(columns={'Country':"Location"})
# Hacemos un merge pero es solo para ordenar los datos, despues los separamos otra vez
df_grouped_merge = pd.merge(df_grouped, data_pm25_2019, on='Location', how='inner')
# Generamos df por separado para hacer los plots
df_grouped_merge['suma'] = df_grouped_merge['Ischemic heart disease'] + df_grouped_merge['Stroke']+df_grouped_merge['Tracheal, bronchus, and lung cancer']
df_grouped_merge_plot_1 = df_grouped_merge[["Location","Ischemic heart disease", "Tracheal, bronchus, and lung cancer","Stroke"]]
df_grouped_merge_plot_2 = df_grouped_merge[["Location","Exposure Mean"]]
# Establecer la columna "Nombre" como índice
df_grouped_merge_plot_1.set_index('Location', inplace=True)
df_grouped_merge_plot_2.set_index('Location', inplace=True)

# Plot
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 10))
# Graficar en la primera subtrama
df_grouped_merge_plot_1.plot(kind='barh', stacked=True, width=0.7, ax=axes[0])
axes[0].set_title('Age-standardised YLL rate per 100,000 2019')
axes[0].set_xlabel('YLL')
axes[0].set_ylabel('')
#axes[0].set_ylabel('Eje Y')

# Graficar en la segunda subtrama

df_grouped_merge_plot_2.plot(kind='barh', width=0.7, ax=axes[1], color='orange')
axes[1].set_title('Average annual population-weighted aPM2.5 2019')
axes[1].set_xlabel('aPM2.5')
#axes[1].set_ylabel('Eje Y')
axes[1].set_ylabel('')
# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Figure 5. DARR change (%) and PMR change (%) for European countries
# Se utilizó el cambio en la proporción de aPM2.5 (concentración anual promedio de partículas finas) y el cambio en la proporción de la tasa de DALY (Años de Vida Ajustados por Discapacidad) (DARR) para evaluar la capacidad de cada país para reducir su contaminación de aPM2.5 y los DALYs al menos hasta el nivel de disminución mediana europea dentro del período analizado.

# %%
# Figure 5. DARR change (%) and PMR change (%) for European countries
# DARR
# DALY rate 1990 country
daly_rate_1990 = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes') & (data['Age'] == 'Age-standardized') & (data['Sex'] == "Both sexes")  & (data['Year'] == 1990)]
# DALY rate 1990 EU
median_1990 =daly_rate_1990['Value'].median()
# DALY rate 2019 country
daly_rate_2019 = data[(data['Measure'] == 'DALYs') & (data['Metric'] == 'Rate') & (data['Risk'] == 'Air pollution') & (data['Cause'] == 'All causes') & (data['Age'] == 'Age-standardized') & (data['Sex'] == "Both sexes")  & (data['Year'] == 2019)]
# DALY rate 2019 EU
median_2019 = daly_rate_2019['Value'].median()
# DARR change 1990-2019
daly_rate = pd.merge(daly_rate_1990, daly_rate_2019, on='Location', how='inner')
daly_rate.columns
daly_rate = daly_rate.rename(columns={'Value_x':"value_1990", 'Value_y':"value_2019"})
#Generamos un df nuevo y solo nos quedamos con las columnas del nombre de los paises y el % de cambio calculado
DARR = daly_rate[['Location', 'value_1990', 'value_2019']]
DARR
DARR['DARR_1990'] =  DARR['value_1990'] / median_1990
DARR['DARR_2019'] =  DARR['value_2019'] / median_2019

DARR['DARR_change_1990_2019'] = ((DARR['DARR_1990'] - DARR['DARR_2019'])/DARR['DARR_1990'])*100
DARR
DARR = DARR.sort_values(by='DARR_change_1990_2019',ascending=False)

### PLOT
# Generamos Gráfico de barras
plt.figure(figsize=(8, 6))
# Crear un gráfico de barras horizontales
plt.barh(DARR['Location'], DARR['DARR_change_1990_2019'], height=0.8)
plt.xlim(-165, 110) 
# Agregar etiquetas a los ejes
plt.xlabel('DARR Change (%)')
plt.ylabel('Location')
plt.yticks( fontsize=7)
# Agregar título
plt.title('Figure 5. DARR change (%)')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-49-6a974f85f241>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DARR['DARR_1990'] =  DARR['value_1990'] / median_1990
# <ipython-input-49-6a974f85f241>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DARR['DARR_2019'] =  DARR['value_2019'] / median_2019
# <ipython-input-49-6a974f85f241>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DARR['DARR_change_1990_2019'] = ((DARR['DARR_1990'] - DARR['DARR_2019'])/DARR['DARR_1990'])*100

# %%
data_pm

# Figure 5. PMR change (%) and PMR change (%) for European countries

# DALY rate 1990 country
PMR_1990 = data_pm[data_pm['Year'] == 1990]
# DALY rate 1990 EU
exposure_median_1990 = PMR_1990['Exposure Mean'].median()
# DALY rate 2019 country
PMR_2019 = data_pm[data_pm['Year'] == 2019]# DALY rate 2019 EU
exposure_median_2019 = PMR_2019['Exposure Mean'].median()
# DARR change 1990-2019
PMR_merge = pd.merge(PMR_1990, PMR_2019, on='Country', how='inner')
PMR_merge
# daly_rate.columns
PMR_merge = PMR_merge.rename(columns={'Exposure Mean_x':"value_1990", 'Exposure Mean_y':"value_2019"})
# #Generamos un df nuevo y solo nos quedamos con las columnas del nombre de los paises y el % de cambio calculado
PMR_merge.columns
PMR = PMR_merge[['Country', 'value_1990', 'value_2019']]
#PMR
PMR['PMR_1990'] =  PMR['value_1990'] / exposure_median_1990
PMR['PMR_2019'] =  PMR['value_2019'] / exposure_median_2019

PMR['PMR_change_1990_2019'] = ((PMR['PMR_1990'] - PMR['PMR_2019'])/PMR['PMR_1990'])*100
# DARR
PMR = PMR.sort_values(by='PMR_change_1990_2019',ascending=False)

# ### PLOT
# # Generamos Gráfico de barras
plt.figure(figsize=(8, 6))
# Crear un gráfico de barras horizontales
plt.barh(PMR['Country'], PMR['PMR_change_1990_2019'], height=0.8)
plt.xlim(-100, 20) 
# Agregar etiquetas a los ejes
plt.xlabel('PMR Change (%)')
plt.ylabel('Location')
plt.yticks( fontsize=7)
# Agregar título
plt.title('Figure 5. PMR change (%)')

# Mostrar el gráfico
plt.show()
# Out:
# <ipython-input-50-66fbcd3f1900>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PMR['PMR_1990'] =  PMR['value_1990'] / exposure_median_1990
# <ipython-input-50-66fbcd3f1900>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PMR['PMR_2019'] =  PMR['value_2019'] / exposure_median_2019
# <ipython-input-50-66fbcd3f1900>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PMR['PMR_change_1990_2019'] = ((PMR['PMR_1990'] - PMR['PMR_2019'])/PMR['PMR_1990'])*100

# %%
# Idem anterior pero ponemos los plots en el mismo como subplot
# Hacemos un pre-procesamiento para unir los dos df en uno mismo y ordenar los datos seguro PMR
PMR = PMR.rename(columns={'Country':"Location"})
merge_DARR_PMR = pd.merge(PMR, DARR, on='Location', how='inner')
merge_DARR_PMR.set_index('Location', inplace=True)
merge_DARR_PMR = merge_DARR_PMR.sort_values(by='PMR_change_1990_2019',ascending=False)
PMR_change_1990_2019 = merge_DARR_PMR[["PMR_change_1990_2019"]]
DARR_change_1990_2019 = merge_DARR_PMR[["DARR_change_1990_2019"]]

# Plot
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 10))
# Graficar en la primera subtrama
PMR_change_1990_2019.plot(kind='barh',width=0.7, ax=axes[0])
axes[0].set_title('PMR change (%)')
axes[0].set_xlabel('PMR change (%)')
axes[0].set_ylabel('')
axes[0].set_xlim(-110,25)  
#axes[0].set_ylabel('Eje Y')

# Graficar en la segunda subtrama

DARR_change_1990_2019.plot(kind='barh', width=0.7, ax=axes[1], color='orange')
axes[1].set_title('DARR change (%)')
axes[1].set_xlabel('DARR change (%)')
#axes[1].set_ylabel('Eje Y')
axes[1].set_ylabel('')
#axes[1].set_xlim(-190,110) 
axes[1].set_xticks(range(-160, 110, 20)) 
# Ajustar el diseño
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Supplementary Figure S1: Median European aPM2.5 concentration from 1990 to 2019

# %%
data_pm = pd.read_csv("EU_PM25.csv")

# Calcular el promedio de concentraciones por año
promedio_por_año = data_pm.groupby('Year')['Exposure Mean'].mean().reset_index()
promedio_por_año
# # Graficar el resultado
plt.figure(figsize=(8, 6))
plt.plot(promedio_por_año['Year'], promedio_por_año['Exposure Mean'], marker='o')
plt.xlabel('Year')
plt.ylabel('PM2.5 (ug/m3)')
plt.title('Supplementary Figure S1: Median European aPM2.5 concentration from 1990 to 2019.')
#plt.xlim(1990, 2019) 
plt.yticks(range(0, 23, 2))
plt.xticks(range(1990,2020,1), rotation='vertical')
plt.show()
promedio_por_año
# Out:
#     Year  Exposure Mean
# 0   1990      20.774651
# 1   1995      19.799535
# 2   2000      18.549535
# 3   2005      17.353488
# 4   2010      17.159535
# 5   2011      17.653953
# 6   2012      16.048140
# 7   2013      15.482093
# 8   2014      15.119302
# 9   2015      14.908605
# 10  2016      13.693721
# 11  2017      13.846977
# 12  2018      13.939302
# 13  2019      13.803488

# %% [markdown]
# # Supplementary Figure S3

# %%
YLL_sup3 = filtrado (data = data, Measure = "YLLs", Metric = 'Rate', Risk = 'Air pollution', Cause='All causes', Age = "Age-standardized", Sex="Both sexes", Year=2019)

data_pm_2019 = data_pm[data_pm['Year'] == 2019]
len(data_pm_2019)
data_pm_2019 = data_pm_2019.rename(columns={'Country':"Location"})
# Union de las tablas de 1990 - 2019 para ser comparadas
supp3 = pd.merge(YLL_sup3, data_pm_2019, on='Location', how='inner')
supp3

slope_supp3 , intercept_supp3 , r_supp3 , _supp3 , stderr_supp3  = scipy.stats.linregress(supp3['Exposure Mean'] , supp3['Value'])

x = supp3['Exposure Mean'].values.reshape(-1,1)
y = supp3['Value'].values.reshape(-1,1)   
        
linear_regresion_supp = LinearRegression()
linear_regresion_supp.fit(x,y)
li_predict_supp = linear_regresion_supp.predict(x)




plt.figure(figsize=(8, 6))
plt.scatter(supp3['Exposure Mean'], supp3['Value'], marker='o')
plt.plot(x,li_predict_supp,c="blue",linestyle="-",linewidth=2.5)
plt.yticks(range(0, 3100, 1000))
plt.xticks(range(0,45,10))

# Calcular el coeficiente de Spearman
coef_spearman, p_value = spearmanr(supp3['Exposure Mean'], supp3['Value'])
print("Spearman r = ",round(coef_spearman,3),"p value = ", p_value)
# Out:
# Spearman r =  0.911 p value =  2.083795853909087e-17

# %% [markdown]
# # Supplementary Table S1

# %%
data_pm_2019 = data_pm[data_pm['Year'] == 2019]
data_pm_1990 = data_pm[data_pm['Year'] == 1990]
supp_tabla1 = pd.merge(data_pm_1990, data_pm_2019, on='Country', how='inner')
supp_tabla1 = supp_tabla1.rename(columns={'Exposure Mean_x':"Exposure Mean 1990", 'Exposure Mean_y':"Exposure Mean 2019"})
supp_tabla1_sub = supp_tabla1[["Country","Exposure Mean 1990","Exposure Mean 2019"]]
supp_tabla1_sub["difference"] = round(((supp_tabla1_sub["Exposure Mean 2019"] - supp_tabla1_sub["Exposure Mean 1990"])/supp_tabla1_sub["Exposure Mean 1990"])*100,1)

supp_tabla1_sub = supp_tabla1_sub.sort_values(by='Country')
supp_tabla1_sub
# Out:
# <ipython-input-198-787607e75060>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supp_tabla1_sub["difference"] = round(((supp_tabla1_sub["Exposure Mean 2019"] - supp_tabla1_sub["Exposure Mean 1990"])/supp_tabla1_sub["Exposure Mean 1990"])*100,1)
#                    Country  Exposure Mean 1990  Exposure Mean 2019  difference
# 29                 Albania               24.90               18.60       -25.3
# 10                 Andorra               14.30                9.07       -36.6
# 25                 Austria               21.30               12.20       -42.7
# 30                 Belarus               25.20               16.40       -34.9
# 24                 Belgium               21.10               12.70       -39.8
# 41  Bosnia and Herzegovina               36.70               29.50       -19.6
# 37                Bulgaria               28.00               19.40       -30.7
# 32                 Croatia               26.10               18.50       -29.1
# 15                  Cyprus               17.50               15.60       -10.9
# 33                 Czechia               26.10               16.80       -35.6
# 13                 Denmark               17.30                9.79       -43.4
# 3                  Estonia                9.91                5.89       -40.6
# 1                  Finland                8.80                5.57       -36.7
# 18                  France               18.60               11.40       -38.7
# 22                 Germany               20.60               11.80       -42.7
# 21                  Greece               20.40               14.30       -29.9
# 31                 Hungary               25.60               16.50       -35.5
# 0                  Iceland                7.22                5.70       -21.1
# 8                  Ireland               12.70                7.85       -38.2
# 35                   Italy               26.90               16.10       -40.1
# 23                  Latvia               20.90               12.00       -42.6
# 16               Lithuania               17.50               10.40       -40.6
# 11              Luxembourg               16.20               10.10       -37.7
# 12                   Malta               16.50               13.00       -21.2
# 4                   Monaco               10.20               11.70        14.7
# 38              Montenegro               33.10               21.30       -35.6
# 20             Netherlands               19.90               12.00       -39.7
# 42         North Macedonia               45.60               30.30       -33.6
# 6                   Norway               11.80                6.64       -43.7
# 39                  Poland               33.30               22.60       -32.1
# 5                 Portugal               11.60                8.25       -28.9
# 27     Republic of Moldova               22.40               13.70       -38.8
# 26                 Romania               22.10               15.70       -29.0
# 19      Russian Federation               18.80               11.60       -38.3
# 7               San Marino               12.60                9.91       -21.3
# 40                  Serbia               35.80               25.40       -29.1
# 36                Slovakia               27.20               18.40       -32.4
# 34                Slovenia               26.60               17.00       -36.1
# 9                    Spain               14.00                9.73       -30.5
# 2                   Sweden                9.78                5.65       -42.2
# 17             Switzerland               18.00                9.90       -45.0
# 28                 Ukraine               22.80               14.50       -36.4
# 14          United Kingdom               17.40               10.10       -42.0

# %% [markdown]
# # Supplementary Table S2. Deaths, age-standardised death rates and DALY rate attributable to air pollution for European countries in 2019.

# %%
sup_tabla_2_muertes_num = filtrado (data = data, Measure = "Deaths", Metric = 'Number', Risk = 'Air pollution', Cause='All causes', Age = "All ages", Sex="Both sexes", Year=2019)
len(sup_tabla_2_muertes_num)
sup_tabla_2_muertes_rate = filtrado (data = data, Measure = "Deaths", Metric = 'Rate', Risk = 'Air pollution', Cause='All causes', Age = "Age-standardized", Sex="Both sexes", Year=2019)
len(sup_tabla_2_muertes_rate)
sup_tabla_2_muertes_rate

sup_tabla_2_DALYs_rate = filtrado (data = data, Measure = "DALYs", Metric = 'Rate', Risk = 'Air pollution', Cause='All causes', Age = "Age-standardized", Sex="Both sexes", Year=2019)
len(sup_tabla_2_DALYs_rate)
sup_tabla_2_DALYs_rate

sup_tabla_2 = pd.merge(sup_tabla_2_muertes_num, sup_tabla_2_muertes_rate, on='Location', how='inner')
sup_tabla_2 = sup_tabla_2.rename(columns={'Value_x':"muertes_num", 'Value_y':"muertes_rate"})
sup_tabla_2 = sup_tabla_2[["Location","muertes_num","muertes_rate"]]
sup_tabla_2 = pd.merge(sup_tabla_2, sup_tabla_2_DALYs_rate, on='Location', how='inner')

sup_tabla_2 = sup_tabla_2.rename(columns={'Value':"DALYs_rate"})
sup_tabla_2 = sup_tabla_2[["Location","muertes_num","muertes_rate","DALYs_rate"]]
sup_tabla_2 = sup_tabla_2.sort_values(by='Location')
sup_tabla_2
# Out:
#                   Location  muertes_num  muertes_rate  DALYs_rate
# 40                 Albania      2276.27         54.94     1250.68
# 28                 Andorra        13.51          9.06      209.63
# 16                 Austria      2654.94         13.53      317.61
# 18                 Belarus      8569.64         53.39     1217.23
# 30                 Belgium      3786.87         14.89      359.76
# 0   Bosnia and Herzegovina      4836.80         84.38     1883.42
# 2                 Bulgaria     11013.15         76.10     1777.59
# 1                  Croatia      3389.88         36.94      842.58
# 41                  Cyprus       457.99         26.08      535.32
# 3                  Czechia      6606.62         30.40      738.25
# 38                 Denmark      1466.57         12.02      269.91
# 29                 Estonia       206.77          7.29      177.96
# 42                 Finland       416.63          3.14       79.32
# 5                   France     14333.67          9.34      230.13
# 7                  Germany     29252.18         14.03      351.13
# 6                   Greece      6218.68         23.13      546.39
# 11                 Hungary      8616.98         43.76     1080.57
# 8                  Iceland        18.76          3.14       79.09
# 24                 Ireland       552.47          7.24      165.81
# 21                   Italy     27902.06         16.50      380.63
# 36                  Latvia      1233.65         29.07      674.07
# 39               Lithuania      1340.27         21.84      502.00
# 10              Luxembourg       102.50          9.57      243.11
# 26                   Malta       161.80         16.71      403.35
# 9                   Monaco        16.43         15.66      365.97
# 14              Montenegro       737.86         77.63     1728.81
# 19             Netherlands      4969.91         13.86      323.45
# 23         North Macedonia      3301.39        118.42     2501.87
# 31                  Norway       454.02          4.35      107.75
# 32                  Poland     31119.24         43.38     1057.88
# 15                Portugal      2410.80          8.81      206.58
# 35     Republic of Moldova      2419.33         42.59     1055.68
# 17                 Romania     17138.23         45.28     1098.09
# 4       Russian Federation     77516.50         33.37      799.58
# 22              San Marino         6.64          9.19      226.81
# 12                  Serbia     12667.57         82.93     1762.12
# 27                Slovakia      3573.43         39.42      894.91
# 13                Slovenia       939.99         19.90      492.17
# 34                   Spain     11785.01         10.37      244.99
# 20                  Sweden       758.17          3.23       79.17
# 33             Switzerland      1607.59          8.17      198.40
# 37                 Ukraine     46129.14         60.95     1451.70
# 25          United Kingdom     15026.21         11.19      286.62

# %% [markdown]
# # Supplementary Table S3. Ratio of YLL rate attributable to air pollution and death rate attributable to air pollution in 1990 and 2019 for European countries.

# %%
YLL_2019 = filtrado (data = data, Measure = "YLLs", Metric = 'Rate', Risk = 'Air pollution', Cause='All causes', Age = "Age-standardized", Sex="Both sexes", Year=2019)
YLL_1990 = filtrado (data = data, Measure = "YLLs", Metric = 'Rate', Risk = 'Air pollution', Cause='All causes', Age = "Age-standardized", Sex="Both sexes", Year=1990)

# 
YLL_2019 = YLL_2019[['Location', "Value"]]
YLL_1990 = YLL_1990[['Location', "Value"]]

YLL_merge = pd.merge(YLL_1990, YLL_2019, on='Location', how='inner')
YLL_merge = YLL_merge.rename(columns={'Value_x':"YLL_1990", 'Value_y':"YLL_2019"})
# Medianas Europeas
YLL_1990_median = YLL_merge['YLL_1990'].median()
YLL_2019_median =YLL_merge['YLL_2019'].median()

# YRR 1990
YLL_merge['YRR_1990'] = YLL_merge['YLL_1990'] / YLL_1990_median
# YRR 2019
YLL_merge['YRR_2019'] = YLL_merge['YLL_2019'] / YLL_2019_median

# YRR change (%)
YLL_merge['YRR_change'] = round(((YLL_merge['YRR_1990'] - YLL_merge['YRR_2019'])/YLL_merge['YRR_1990'] )*100,2)
YLL_merge = YLL_merge.sort_values(by='Location')
YLL_merge
# Out:
#                   Location  YLL_1990  YLL_2019  YRR_1990  YRR_2019  YRR_change
# 3                  Albania   3697.05   1112.28  3.712941  3.461488        6.77
# 15                 Andorra    426.36    167.56  0.428193  0.521458      -21.78
# 21                 Austria    889.80    253.07  0.893625  0.787570       11.87
# 8                  Belarus   2072.46   1122.16  2.081368  3.492235      -67.79
# 22                 Belgium    931.89    282.13  0.935896  0.878007        6.19
# 6   Bosnia and Herzegovina   3262.32   1593.89  3.276343  4.960290      -51.40
# 4                 Bulgaria   3271.20   1589.52  3.285261  4.946690      -50.57
# 1                  Croatia   1962.28    688.02  1.970715  2.141163       -8.65
# 25                  Cyprus   1088.10    435.07  1.092777  1.353966      -23.90
# 5                  Czechia   2129.60    557.08  2.138754  1.733669       18.94
# 24                 Denmark    940.55    224.37  0.944593  0.698254       26.08
# 14                 Estonia   1292.84    145.70  1.298397  0.453428       65.08
# 20                 Finland    417.76     60.86  0.419556  0.189400       54.86
# 26                  France    563.79    193.60  0.566213  0.602496       -6.41
# 27                 Germany    995.72    269.65  1.000000  0.839168       16.08
# 28                  Greece    980.65    457.08  0.984865  1.422463      -44.43
# 2                  Hungary   2704.72    904.37  2.716346  2.814459       -3.61
# 30                 Iceland    232.22     62.56  0.233218  0.194691       16.52
# 31                 Ireland    761.77    131.63  0.765044  0.409641       46.46
# 29                   Italy    972.34    292.12  0.976520  0.909097        6.90
# 19                  Latvia   1997.98    589.15  2.006568  1.833473        8.63
# 18               Lithuania   1470.42    441.81  1.476740  1.374942        6.89
# 32              Luxembourg    807.00    177.55  0.810469  0.552547       31.82
# 35                   Malta    918.57    321.33  0.922518  1.000000       -8.40
# 41                  Monaco    366.45    304.33  0.368025  0.947095     -157.35
# 10              Montenegro   2421.89   1512.77  2.432300  4.707839      -93.56
# 34             Netherlands    892.58    257.41  0.896417  0.801077       10.64
# 0          North Macedonia   4155.67   2214.93  4.173533  6.893007      -65.16
# 33                  Norway    500.21     80.55  0.502360  0.250677       50.10
# 11                  Poland   2828.09    872.24  2.840246  2.714468        4.43
# 36                Portugal    693.84    159.40  0.696822  0.496063       28.81
# 17     Republic of Moldova   3520.48    950.00  3.535612  2.956462       16.38
# 9                  Romania   2970.05    967.34  2.982816  3.010425       -0.93
# 16      Russian Federation   1822.47    731.03  1.830304  2.275013      -24.30
# 40              San Marino    332.36    176.33  0.333789  0.548751      -64.40
# 7                   Serbia   3585.65   1512.28  3.601063  4.706314      -30.69
# 13                Slovakia   2308.82    761.06  2.318744  2.368469       -2.14
# 12                Slovenia   1418.05    373.50  1.424145  1.162356       18.38
# 37                   Spain    606.34    185.52  0.608946  0.577350        5.19
# 39                  Sweden    345.09     61.68  0.346573  0.191952       44.61
# 42             Switzerland    676.45    152.48  0.679358  0.474528       30.15
# 23                 Ukraine   2089.63   1354.20  2.098612  4.214359     -100.82
# 38          United Kingdom    937.08    217.67  0.941108  0.677403       28.02

# %%
Deaths_2019 = filtrado (data = data, Measure = "Deaths", Metric = 'Rate', Risk = 'Air pollution', Cause='All causes', Age = "Age-standardized", Sex="Both sexes", Year=2019)
Deaths_1990 = filtrado (data = data, Measure = "Deaths", Metric = 'Rate', Risk = 'Air pollution', Cause='All causes', Age = "Age-standardized", Sex="Both sexes", Year=1990)

# 
Deaths_2019 = Deaths_2019[['Location', "Value"]]
Deaths_1990 = Deaths_1990[['Location', "Value"]]

Deaths_merge = pd.merge(Deaths_1990, Deaths_2019, on='Location', how='inner')
Deaths_merge = Deaths_merge.rename(columns={'Value_x':"DRR_1990", 'Value_y':"DRR_2019"})
# Medianas Europeas
DRR_1990_median = Deaths_merge['DRR_1990'].median()
DRR_2019_median =Deaths_merge['DRR_2019'].median()

# YRR 1990
Deaths_merge['DRR_1990'] = Deaths_merge['DRR_1990'] / DRR_1990_median
# YRR 2019
Deaths_merge['DRR_2019'] = Deaths_merge['DRR_2019'] / DRR_2019_median

# YRR change (%)
Deaths_merge['DRR_change'] = round(((Deaths_merge['DRR_1990'] - Deaths_merge['DRR_2019'])/Deaths_merge['DRR_1990'] )*100,2)
Deaths_merge = Deaths_merge.sort_values(by='Location')
Deaths_merge
# Out:
#                   Location  DRR_1990  DRR_2019  DRR_change
# 2                  Albania  2.933987  3.287852      -12.06
# 17                 Andorra  0.438088  0.542190      -23.76
# 5                  Austria  0.891978  0.809695        9.22
# 6                  Belarus  1.881576  3.195093      -69.81
# 27                 Belgium  0.931386  0.891083        4.33
# 38  Bosnia and Herzegovina  2.992599  5.049671      -68.74
# 1                 Bulgaria  3.070814  4.554159      -48.30
# 25                 Croatia  1.892378  2.210652      -16.82
# 10                  Cyprus  1.252250  1.560742      -24.63
# 0                  Czechia  2.025005  1.819270       10.16
# 34                 Denmark  0.908982  0.719330       20.86
# 35                 Estonia  1.182236  0.436266       63.10
# 4                  Finland  0.392879  0.187911       52.17
# 26                  France  0.568114  0.558947        1.61
# 7                  Germany  0.997199  0.839617       15.80
# 24                  Greece  1.000000  1.384201      -38.42
# 31                 Hungary  2.340068  2.618791      -11.91
# 12                 Iceland  0.220644  0.187911       14.84
# 29                 Ireland  0.775355  0.433273       44.12
# 21                   Italy  0.980996  0.987433       -0.66
# 19                  Latvia  1.830566  1.739677        4.97
# 40               Lithuania  1.363073  1.307002        4.11
# 11              Luxembourg  0.803361  0.572711       28.71
# 37                   Malta  0.925385  1.000000       -8.06
# 30                  Monaco  0.365473  0.937163     -156.42
# 28              Montenegro  2.169634  4.645721     -114.12
# 15             Netherlands  0.880576  0.829443        5.81
# 8          North Macedonia  3.667133  7.086774      -93.25
# 32                  Norway  0.484097  0.260323       46.22
# 3                   Poland  2.488098  2.596050       -4.34
# 23                Portugal  0.699940  0.527229       24.68
# 20     Republic of Moldova  3.130626  2.548773       18.59
# 33                 Romania  2.590918  2.709755       -4.59
# 39      Russian Federation  1.634927  1.997008      -22.15
# 13              San Marino  0.342869  0.549970      -60.40
# 9                   Serbia  3.277856  4.962896      -51.41
# 36                Slovakia  2.085417  2.359066      -13.12
# 14                Slovenia  1.376675  1.190904       13.49
# 41                   Spain  0.618124  0.620586       -0.40
# 18                  Sweden  0.350470  0.193297       44.85
# 42             Switzerland  0.690538  0.488929       29.20
# 22                 Ukraine  1.983997  3.647516      -83.85
# 16          United Kingdom  0.918984  0.669659       27.13
